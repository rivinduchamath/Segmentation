# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("users.csv", sep=',', index_col=False, dtype='unicode')

# %%
df.shape
# Out:
# (38321, 27)

# %%
df.dtypes
# Out:
# id                    object
# first_name            object
# last_name             object
# username              object
# email                 object
# password              object
# remember_token        object
# avatar                object
# avatar_sync           object
# mobile_no             object
# zipcode               object
# city                  object
# address               object
# default_city_id       object
# shop_name             object
# description           object
# state                 object
# created_at            object
# updated_at            object
# email_updates         object
# enable_cc             object
# commision             object
# commision_type        object
# is_agreed             object
# agreed_at             object
# stripe_customer_id    object
# referral_vendor       object
# dtype: object

# %%
df.head()
# Out:
#   id first_name last_name username                       email  \
# 0  1      Shany  Gottlieb      NaN          anne77@example.org
# 1  2     Jordon   Weimann      NaN      nils.jones@example.com
# 2  3     Kamryn  Shanahan      NaN  hamill.heloise@example.net
# 3  5     German    Heller      NaN          ohaley@example.net
# 4  6    Martine   Hagenes      NaN   goodwin.amani@example.net
#
#                password                                     remember_token  \
# 0    k8b-dGU9&1vu$RsDw@  hitOzrYg8DDmUbTbudzE222UK0DfeYgPmQ7DRVp9ypGDwX...
# 1  -`m+NFp!E!ypLPc+23p|  kSvP8DxH5rnD7qwRph6JxA5stUkzkSKrIhh9sJBvhqnvjn...
# 2        %LXAHCc?E`5Ts*  j6ZkTzj1XbCEgCHKG8171mO0uB7ggRgDXZ6QkhgRCWU6m7...
# 3   U:T;J_m_6)-/o:0i;yt  XovySJwAEHwlD7PdcLo23eIScLGR3xFzT7oKszDOdFzZbi...
# 4              Hb~#q\T3  YrlCGep8Q3dNnAtive6DNDfxq6TCSfV7KjTQwWksUhHu1t...
#
#   avatar avatar_sync     mobile_no  ...           created_at  \
# 0    NaN           1  +12025550186  ...  2016-04-26 16:48:28
# 1    NaN           0  +12025550186  ...  2016-04-26 18:18:06
# 2    NaN           1  +12025550186  ...  2016-04-26 20:45:02
# 3    NaN           0  +12025550186  ...  2016-04-27 11:34:01
# 4    NaN           0  +12025550186  ...  2016-04-27 13:17:01
#
#             updated_at                                      email_updates  \
# 0  2018-10-02 03:29:54  {"admin_digest": {"active": 1, "frequencies": ...
# 1  2018-10-02 03:30:25                                                NaN
# 2  2018-11-08 16:02:52                                                NaN
# 3  2019-03-07 09:06:36  {"admin_digest": {"active": 1, "frequencies": ...
# 4  2019-03-11 13:02:49                                                NaN
#
#   enable_cc commision commision_type is_agreed            agreed_at  \
# 0         0      0.00            NaN         1                  NaN
# 1         0      0.00            NaN         1                  NaN
# 2         0      0.00            NaN         1                  NaN
# 3         1      0.00            NaN         1                  NaN
# 4         0      0.00            NaN         1  2019-03-11 07:32:27
#
#   stripe_customer_id referral_vendor
# 0                NaN               0
# 1                NaN               0
# 2                NaN               0
# 3                NaN               0
# 4                NaN               0
#
# [5 rows x 27 columns]

# %%
df2 = pd.read_csv("abandoned.csv", sep=',', index_col=False, dtype='unicode') 
# Get Data From abandoned_reservation table

# %%
df2.drop(["mobile_no","is_reservation_done","created_at","updated_at","email","start_date","delivery_area_id","status","user_agent","keywords","origin","item_quantity","displayed_softblock_notification","logs","abandoned_order_id","end_date","cart_id","pickup_address","follow_up_sent","dropoff_address","reservation_page_version","id","customer_height","customer_height_inch","customer_weight","timezone"],axis=1, inplace=True)
# Remove Columns

# %%
df2.head()
# Out:
#   user_id item_id
# 0       1      27
# 1       1      28
# 2       0      47
# 3       0       1
# 4       6      28

# %%
df3 = pd.read_csv("user_city.csv", sep=',', index_col=False, dtype='unicode') 
# Get Data From user_city table

# %%
df3.drop(["created_at","updated_at","id"],axis=1, inplace=True)
# Remove Columns

# %%
df3.head()
# Out:
#   user_id city_id
# 0       5       1
# 1       5       2
# 2     618       1
# 3     618       2
# 4      15       1

# %%
df4 = pd.read_csv("order_id_order_status_id_user_id_os_status.csv", sep=',', index_col=False, dtype='unicode') 
# select order_id , order_status_id , user_id , os.status from order_histories oh left JOIN order_status os  On oh.order_status_id  = os.id

# %%
df4.head()
# Out:
#   order_id order_status_id user_id           status
# 0    37385               2   35062  ORDER_CONFIRMED
# 1    37386               2   35128  ORDER_CONFIRMED
# 2    37386              10   35130   ORDER_ACCEPTED
# 3    37387               2   35062  ORDER_CONFIRMED
# 4    37388               2   35062  ORDER_CONFIRMED

# %%
df5 = pd.read_csv("orderIDandITEM.csv", sep=',', index_col=False, dtype='unicode') 
# SELECT order_id, item_id , i.title from reservations r left join items i  On i.id  = r.item_id

# %%
 df5.head()
# Out:
#   order_id item_id                   title
# 0        1       3  Standard Baby Stroller
# 1        3       1       Jogging Stroller
# 2        4      12        Toddler car seat
# 3        5       1       Jogging Stroller
# 4        6       3  Standard Baby Stroller

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/rivindu/.local/lib/python3.10/site-packages (1.1.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/rivindu/.local/lib/python3.10/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/rivindu/.local/lib/python3.10/site-packages (from scikit-learn) (1.9.1)
# Requirement already satisfied: joblib>=1.0.0 in /home/rivindu/.local/lib/python3.10/site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/rivindu/.local/lib/python3.10/site-packages (from scikit-learn) (1.23.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
X = df5.iloc[:,[0,1]].values

# %%
print(X)
# Out:
# [['1' '3']
#  ['3' '1']
#  ['4' '12']
#  ...
#  ['46059' '94']
#  ['46060' '94']
#  ['46061' '138']]

# %%
wcss = []
for i in range(1,11):
 kmeans = KMeans(n_clusters=i, init='k-means++',random_state=42)
 kmeans.fit(X)
 wcss.append(kmeans.inertia_)

# %%
sns.set()
plt.plot(range(1,11),wcss)
plt.title('graph')
plt.xlabel('Number')
plt.xlabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters=5, init='k-means++',random_state=0)
Y = kmeans.fit_predict(X)
print(Y)
# Out:
# [0 0 0 ... 4 4 4]

# %%
plt.figure(figsize=(8,8))
plt.scatter(X[Y==0,0],X[Y==0,1],s=50,c='green', label='Cluster 1')
plt.scatter(X[Y==1,0],X[Y==1,1],s=50,c='red', label='Cluster 2')
plt.scatter(X[Y==2,0],X[Y==2,1],s=50,c='yellow', label='Cluster 3')
plt.scatter(X[Y==3,0],X[Y==3,1],s=50,c='violet', label='Cluster 4')
plt.scatter(X[Y==4,0],X[Y==4,1],s=50,c='blue', label='Cluster 5')

plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1],s=100, c="cyan", label ='Cenroids')

plt.title('Order Items')
plt.xlabel('Number')
plt.xlabel('WCSS')
plt.show()
